# %% [markdown]
# <a href="https://colab.research.google.com/github/seolibek/Tufts2024/blob/main/umap_trial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # UMAP on HSI data - SalinasA
#
# Use as a reference when running with other datasets to generate accuracy plots (cleaned up code, significantly)

# %%
from umap_script import loadHSI, show_clusterable_embedding, visualize_umap, compare_umap

import numpy as np
import random
import matplotlib.pyplot as plt
import umap

# %% [markdown]
# # UMAP on HSI data - SalinasA
#
# Calling cleaned up versions of functions from umap_script python file.
#
# Notes:
# UMAP accepts a two dimensional image. Thus, for example, when it works with MNIST, it just accepts MNIST.data. (See: documentation)
#
# In our case, with HSI, there are three dimensions. We seek to extend the application of 2D images and UMAP to HSI imagery.

# %% [markdown]
# Below, we load in our dataset.
#
# This is a rewritten version of the MATLAB script from prewritten works (notably, Dr. Murphy's linked repositories)
#
# (Updated from the github version in my repository, to fix small casting errors consistent with typical errors in translation from MATLAB to Python).

# %%
salinasA_path = 'data/SalinasA_corrected.mat'
salinasA_gt_path = 'data/SalinasA_gt.mat'

X, M, N, D, HSI, GT, Y, n, K = loadHSI(salinasA_path, salinasA_gt_path, 'salinasA_corrected', 'salinasA_gt')

# %%
import importlib
import umap

# Reload the module
importlib.reload(umap)
#i was going crazy
# Out:
# <module 'umap' from '/opt/anaconda3/envs/csci1470/lib/python3.10/site-packages/umap/__init__.py'>

# %%
clust_emb = show_clusterable_embedding(HSI, GT)
print(len(np.unique(GT)))
# Out:
# 7

# %% [markdown]
# Below is a graph based on ground truth? Still working throguh documenation to decipher what this line of code does, specifically.

# %%
clust_emb = show_clusterable_embedding(HSI, GT)
# Out:
# /opt/anaconda3/envs/csci1470/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
# !pip install ffmpeg
# Out:
# Requirement already satisfied: ffmpeg in /opt/anaconda3/envs/csci1470/lib/python3.10/site-packages (1.4)

# %%
testing = visualize_umap(data_reshaped = HSI, ground_truth = GT, n_components=3,title='3D Salinas A')

# %%
compare_umap(HSI, GT, 'Salinas A', compare_dim=True, compare_neighbors=False, tSNE=False)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# UMAP Adjusted Rand Index (ARI): 0.3618853288743502
# PCA Adjusted Rand Index (ARI): 0.3274443123882487
# UMAP Adjusted Rand Index (ARI): 0.39321120724512576
# PCA Adjusted Rand Index (ARI): 0.24454683099340543
# UMAP Adjusted Rand Index (ARI): 0.5404484865993257
# PCA Adjusted Rand Index (ARI): 0.38001187363029676
# UMAP Adjusted Rand Index (ARI): 0.3858917124820444
# PCA Adjusted Rand Index (ARI): 0.3906316801284156
# UMAP Adjusted Rand Index (ARI): 0.5398258910134306
# PCA Adjusted Rand Index (ARI): 0.39839766230288254
# UMAP Adjusted Rand Index (ARI): 0.5415519313551451
# PCA Adjusted Rand Index (ARI): 0.3984423932884777
# UMAP Adjusted Rand Index (ARI): 0.5408762908499203
# PCA Adjusted Rand Index (ARI): 0.39857861975657505
# UMAP Adjusted Rand Index (ARI): 0.5409446301801629
# PCA Adjusted Rand Index (ARI): 0.3986385347953922
# UMAP Adjusted Rand Index (ARI): 0.5412129233365235
# PCA Adjusted Rand Index (ARI): 0.39839766230288254

# %%
compare_umap(HSI, GT, 'Salinas A', compare_dim=False, compare_neighbors=True, tSNE=False)
# Out:
# UMAP Adjusted Rand Index (ARI): 0.062339535926530444
# PCA Adjusted Rand Index (ARI): 0.38001187363029676
# UMAP Adjusted Rand Index (ARI): 0.2116746662840312
# PCA Adjusted Rand Index (ARI): 0.38001187363029676
# UMAP Adjusted Rand Index (ARI): 0.34045236647696986
# PCA Adjusted Rand Index (ARI): 0.38001187363029676
# UMAP Adjusted Rand Index (ARI): 0.5208243276471783
# PCA Adjusted Rand Index (ARI): 0.38001187363029676
# UMAP Adjusted Rand Index (ARI): 0.5116496737162334
# PCA Adjusted Rand Index (ARI): 0.38001187363029676
# UMAP Adjusted Rand Index (ARI): 0.3829385169647932
# PCA Adjusted Rand Index (ARI): 0.38001187363029676
# UMAP Adjusted Rand Index (ARI): 0.5419350942428723
# PCA Adjusted Rand Index (ARI): 0.38001187363029676
# UMAP Adjusted Rand Index (ARI): 0.530408172014437
# PCA Adjusted Rand Index (ARI): 0.38001187363029676
# UMAP Adjusted Rand Index (ARI): 0.5181056840527737
# PCA Adjusted Rand Index (ARI): 0.38001187363029676
# UMAP Adjusted Rand Index (ARI): 0.5143126003813614
# PCA Adjusted Rand Index (ARI): 0.38001187363029676
# UMAP Adjusted Rand Index (ARI): 0.515228788371027
# PCA Adjusted Rand Index (ARI): 0.38001187363029676
